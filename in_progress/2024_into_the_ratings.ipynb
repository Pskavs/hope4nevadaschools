# %% [markdown]
# # **Hope for Nevada Schools - A Look into The Ratings**
# ---

# %% [markdown]
# ## School Rankings - from 1-5 Stars

# %% [markdown]
# While looking at the [Nevada Scorecard](https://nevadareportcard.nv.gov/DI/nv/2024), one of the first things I saw, in small unassuming text, was a link that says: State School Rankings. It has a csv file called "SchoolRatings.csv".

# %%
import pandas as pd
this_year_data = pd.read_csv("2024SchoolRatings.csv")
display(this_year_data.head())
display(this_year_data.tail())
this_year_data.info()
# Out:
#    Year  District Code District Name  NSPF School Code   School Name  \
# 0  2024              1     Churchill            1205.1       Best ES
# 1  2024              1     Churchill            1206.1   Lahontan ES
# 2  2024              1     Churchill            1207.1       Numa ES
# 3  2024              1     Churchill            1301.2  Churchill MS
# 4  2024              1     Churchill            1401.3  Churchill HS
#
#   School Type  Total Index Score Star Rating Title I Status % Proficient ELA  \
# 0     Regular               43.3   Not Rated            YES             28.6
# 1     Regular               55.0   Not Rated            YES              NaN
# 2     Regular               26.8           1            YES             35.6
# 3     Regular               17.0           1            YES             25.9
# 4     Regular               42.5           2             NO             35.3
#
#    ... Advanced Diploma 4-Year Graduation Rate 5-Year Graduation Rate  \
# ...

# %% [markdown]
# ---
# This contains a ranking of each school with 34 columns of data. A list of all the columns are above. Looking at the the table, there are 18 categorical columns (year, district code, district name, school code, school name, school type, Title I status, 95% Participation met mathematics / ELA, Participation Warning / Penalty, Continuing Participation Penalty, CSI, Yrs In Designation as CSI, TSI, Yrs in Designation as TSI, ATSI, Yrs in Designation as ATSI)
